# %% [markdown]
# ## SEASON dataframe & EDA

# %%
#import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import re
import csv
from datetime import datetime
import os
import time
import dask
import json
import pickle

# %%
#opening pickle files
# with open ('EVENT.PKL', 'rb') as f:
#     event_df= pickle.load(f)

# %%
with open ('HOMERUNS.PKL', 'rb') as f:
    homeruns_df= pickle.load(f)

# %%
with open ('OFFENSE.PKL', 'rb') as f:
    offense_df= pickle.load(f)

# %%
with open ('STANDINGS.PKL', 'rb') as f:
    standings_df= pickle.load(f)

# %%
with open ('target_df.PKL', 'rb') as f:
    target_df= pickle.load(f)

# %%
# event_df.gameDate=[x.replace(x[-10:], '', len(event_df.gameDate)) for x in event_df.gameTimeUTC]

# %%
# event_df.drop(['gameTimeUTC'], axis=1, inplace=True)

# %%
# event_df

# %%
homeruns_df
# Out:
#           gameDate playerId      playerName  homeRuns       date
# 67      2018-03-29   607680    Kevin Pillar       1.0 2018-03-29
# 70      2018-03-29   443558     Nelson Cruz       1.0 2018-03-29
# 79      2018-03-29   518934     DJ LeMahieu       1.0 2018-03-29
# 94      2018-03-29   446263      Lucas Duda       1.0 2018-03-29
# 99      2018-03-29   605412       Joe Panik       1.0 2018-03-29
# ...            ...      ...             ...       ...        ...
# 185534  2021-04-30   571745   Mitch Haniger       1.0 2021-04-30
# 185535  2021-04-30   666182     Bo Bichette       1.0 2021-04-30
# 185537  2021-04-30   545341  Randal Grichuk       1.0 2021-04-30
# 185543  2021-04-30   543305     Aaron Hicks       1.0 2021-04-30
# 185552  2021-04-30   608324    Alex Bregman       1.0 2021-04-30
#
# [14840 rows x 5 columns]

# %%
df=pd.read_csv('mlb-player-digital-engagement-forecasting/players.csv')

# %%
df
# Out:
#       playerId          playerName         DOB mlbDebutDate  \
# 0       665482  Gilberto Celestino  1999-02-13   2021-06-02
# 1       593590       Webster Rivas  1990-08-08   2021-05-28
# 2       661269  Vladimir Gutierrez  1995-09-18   2021-05-28
# 3       669212          Eli Morgan  1996-05-13   2021-05-28
# 4       666201         Alek Manoah  1998-01-09   2021-05-27
# ...        ...                 ...         ...          ...
# 2056    672695     Geraldo Perdomo  1999-10-22          NaN
# 2057    672911          Jesus Cruz  1995-04-15          NaN
# 2058    676103         Damon Jones  1994-09-30          NaN
# 2059    676755       Isaac Mattson  1995-07-14          NaN
# 2060    680430       Nick Allgeyer  1996-02-03          NaN
#
#                 birthCity birthStateProvince        birthCountry  \
# 0           Santo Domingo                NaN  Dominican Republic
# 1                   Nagua                NaN  Dominican Republic
# 2                  Havana                NaN                Cuba
# 3     Rancho Palos Verdes                 CA                 USA
# 4               Homestead                 FL                 USA
# ...                   ...                ...                 ...
# 2056        Santo Domingo                NaN  Dominican Republic
# 2057   Salinas de Hidalgo    San Luis Potosi              Mexico
# 2058           Twin Falls                 ID                 USA
# 2059                 Erie                 PA                 USA
# 2060            St. Louis                 MO                 USA
#
#       heightInches  weight primaryPositionCode primaryPositionName  \
# 0               72     170                   8          Outfielder
# 1               73     219                   3          First Base
# 2               73     190                   1             Pitcher
# 3               70     190                   1             Pitcher
# 4               78     260                   1             Pitcher
# ...            ...     ...                 ...                 ...
# 2056            74     203                   6           Shortstop
# 2057            73     230                   1             Pitcher
# 2058            77     233                   1             Pitcher
# 2059            74     205                   1             Pitcher
# 2060            75     210                   1             Pitcher
#
#      playerForTestSetAndFuturePreds
# 0                             False
# 1                              True
# 2                              True
# 3                              True
# 4                              True
# ...                             ...
# 2056                           True
# 2057                          False
# 2058                           True
# 2059                           True
# 2060                           True
#
# [2061 rows x 12 columns]

# %%
#creating a dictionary for player Id: playername
a=list(df.playerId)

# %%
#creating a dictionary for player Id: playername
b=list(df.playerName)

# %%
#dictionary created
dictionary = dict(zip(b,a))

# %%
standings_df
# Out:
#                     teamName    gameDate divisionRank leagueRank wildCardRank  \
# 0               Chicago Cubs  2018-03-29            1          3            3
# 1              Miami Marlins  2018-03-29            4         12           12
# 2              New York Mets  2018-03-29            2          5            5
# 3              Texas Rangers  2018-03-29            5         14           13
# 4             Atlanta Braves  2018-03-29            1          2            2
# ...                      ...         ...          ...        ...          ...
# 16455    St. Louis Cardinals  2021-04-30            2          6            4
# 16456   Arizona Diamondbacks  2021-04-30            4          5            3
# 16457   San Francisco Giants  2021-04-30            1          2          NaN
# 16458   Washington Nationals  2021-04-30            3         11            8
# 16459  Philadelphia Phillies  2021-04-30            1          7          NaN
#
#       xWinLossPct
# 0             0.0
# 1             0.0
# 2             1.0
# 3             0.0
# 4             0.0
# ...           ...
# 16455         0.6
# 16456       0.833
# 16457       0.667
# 16458       0.667
# 16459       0.571
#
# [16460 rows x 6 columns]

# %%
target_df
# Out:
#         engagementMetricsDate playerId                 target1  \
# 0                  2018-01-02   628317    0.011167070542384616
# 1                  2018-01-02   547989     0.04299322158818077
# 2                  2018-01-02   519317      0.9743269048230578
# 3                  2018-01-02   607625   0.0067002423254307695
# 4                  2018-01-02   592547   0.0011167070542384616
# ...                       ...      ...                     ...
# 4249776            2021-05-01   451661                       0
# 4249777            2021-05-01   519301  0.00013148828965292353
# 4249778            2021-05-01   527055                       0
# 4249779            2021-05-01   543484  0.00013148828965292353
# 4249780            2021-05-01   605525  0.00013148828965292353
#
#                        target2               target3              target4
# 0            4.474708171206226  0.005167729742499409    5.735294117647059
# 1            5.593385214007783   0.04503307347035199    2.794117647058824
# 2            56.17704280155642    13.693745570517363    64.16666666666667
# 3           2.6750972762645913  0.005167729742499409   1.8627450980392157
# 4            0.632295719844358  0.002952988424285377   0.9313725490196079
# ...                        ...                   ...                  ...
# 4249776   0.013314249575608294                     0   0.6259246614316604
# 4249777  0.0033285623939020735                     0  0.21622851940366453
# 4249778   0.019971374363412443                     0  0.27313076135199726
# 4249779   0.056585560696335246                     0   1.0242403550699897
# 4249780    0.49928435908531105                     0   0.3869352452486628
#
# [4249781 rows x 6 columns]

# %%
#data cleaning the date 
target_df = target_df.rename(columns = {'engagementMetricsDate': 'gameDate'}, inplace = False)

# %%
#taking only the first 7 digits of the target column
target_df.target1= target_df.target1.map(lambda x: x[0:6])
target_df.target2= target_df.target2.map(lambda x: x[0:6])
target_df.target3= target_df.target3.map(lambda x: x[0:6])
target_df.target4= target_df.target4.map(lambda x: x[0:6])

# %%
# workframe=target_df.T

# %%
df3=pd.read_csv('awards.csv')
df3.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df3
# Out:
#         awardId                         awardName   awardDate awardSeason  \
# 0       VWLCPOY   VWL Comeback Player of the Year  2018-01-15        2017
# 1        VWLPOY           VWL Pitcher of the Year  2018-01-15        2017
# 2        VWLMOY           VWL Manager of the Year  2018-01-15        2017
# 3       VWLRLOY          VWL Reliever of the Year  2018-01-15        2017
# 4       VWLOPOY  VWL Offensive Player of the Year  2018-01-15        2017
# ...         ...                               ...         ...         ...
# 6203      NLPOM            NL Player of the Month  2021-04-30        2021
# 6204  ALRRELMON          AL Reliever of the Month  2021-04-30        2021
# 6205      ALPOM            AL Player of the Month  2021-04-30        2021
# 6206      ALROM            AL Rookie of the Month  2021-04-30        2021
# 6207    ALPITOM           AL Pitcher of the Month  2021-04-30        2021
#
#      playerId         playerName awardPlayerTeamId
# 0      150119      Freddy Garcia               699
# 1      446861  Guillermo Moscoso               699
# 2      492527         Mike Rojas               695
# 3      519246    Andres Santiago               694
# 4      543874        Jose Vargas               699
# ...       ...                ...               ...
# 6203   660670   Ronald Acuna Jr.               144
# 6204   598264        Matt Barnes               111
# 6205   621439       Byron Buxton               142
# 6206   606213    Yermin Mercedes               145
# 6207   543037        Gerrit Cole               147
#
# [6208 rows x 7 columns]

# %%
work= pd.merge(target_df, df3, how='outer', on= ['playerId'])

# %%
offense_df
# Out:
#           gameDate               teamName      playerName atBats  rbi homeRuns
# 0       2018-03-29    Los Angeles Dodgers   Austin Barnes    0.0  0.0      0.0
# 1       2018-03-29         Tampa Bay Rays    Mallex Smith    0.0  0.0      0.0
# 2       2018-03-29  Philadelphia Phillies  Odubel Herrera    0.0  0.0      0.0
# 3       2018-03-29     Los Angeles Angels     Jefry Marte    0.0  0.0      0.0
# 4       2018-03-29     Kansas City Royals   Paulo Orlando    0.0  0.0      0.0
# ...            ...                    ...             ...    ...  ...      ...
# 185673  2021-04-30   San Francisco Giants      Logan Webb    2.0  0.0      0.0
# 185674  2021-04-30      Milwaukee Brewers  Freddy Peralta    2.0  0.0      0.0
# 185675  2021-04-30       Colorado Rockies        Jon Gray    2.0  0.0      0.0
# 185676  2021-04-30       San Diego Padres      Yu Darvish    2.0  0.0      0.0
# 185680  2021-04-30          Miami Marlins     Pablo Lopez    3.0  0.0      0.0
#
# [154290 rows x 6 columns]

# %%
offense_df.playerName.replace(dictionary, inplace=True)

# %%
offense_df.rename(columns={'playerName': 'playerId'}, inplace=True)
offense_df.drop(['teamName'], axis=1, inplace=True)

# %%
work.gameDate.replace('engagementMetricsDate', np.nan).dropna(axis=0, inplace=True)

# %%
work.dropna(axis=0, inplace=True)

# %%
work2= pd.merge(work, offense_df, how='outer', on= ['playerId'])

# %%
work2
# Out:
#          gameDate_x playerId target1 target2 target3 target4    awardId  \
# 0        2018-01-02   628317  0.0111  4.4747  0.0051  5.7352  MLBSECOND
# 1        2018-01-03   628317  0.0063  2.5210  0.0016  2.7669  MLBSECOND
# 2        2018-01-04   628317  0.0035  2.3809  0.0036  3.4393  MLBSECOND
# 3        2018-01-05   628317  0.0033  3.3323  0.0122  4.8496  MLBSECOND
# 4        2018-01-06   628317  0.0239  1.4407  0.0015  2.3712  MLBSECOND
# ...             ...      ...     ...     ...     ...     ...        ...
# 6495689         NaN   622256     NaN     NaN     NaN     NaN        NaN
# 6495690         NaN   676604     NaN     NaN     NaN     NaN        NaN
# 6495691         NaN   664875     NaN     NaN     NaN     NaN        NaN
# 6495692         NaN   666163     NaN     NaN     NaN     NaN        NaN
# 6495693         NaN   670955     NaN     NaN     NaN     NaN        NaN
#
#                    awardName   awardDate awardSeason   playerName  \
# 0        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 1        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 2        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 3        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 4        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# ...                      ...         ...         ...          ...
# 6495689                  NaN         NaN         NaN          NaN
# 6495690                  NaN         NaN         NaN          NaN
# 6495691                  NaN         NaN         NaN          NaN
# 6495692                  NaN         NaN         NaN          NaN
# 6495693                  NaN         NaN         NaN          NaN
#
#         awardPlayerTeamId  gameDate_y atBats  rbi homeRuns
# 0                     142         NaN    NaN  NaN      NaN
# 1                     142         NaN    NaN  NaN      NaN
# 2                     142         NaN    NaN  NaN      NaN
# 3                     142         NaN    NaN  NaN      NaN
# 4                     142         NaN    NaN  NaN      NaN
# ...                   ...         ...    ...  ...      ...
# 6495689               NaN  2021-04-28    0.0  0.0      0.0
# 6495690               NaN  2021-04-28    1.0  0.0      0.0
# 6495691               NaN  2021-04-29    0.0  0.0      0.0
# 6495692               NaN  2021-04-30    3.0  1.0      0.0
# 6495693               NaN  2021-04-30    1.0  0.0      0.0
#
# [6495694 rows x 16 columns]

# %%
work2.rename(columns={'gameDate_x': 'gameDate'}, inplace=True)

# %%
work2.drop(['gameDate_y'], axis=1, inplace=True)

# %%
# work3.isna().sum()

# %%
work2.playerId.dropna(axis=0, inplace=True)

# %%
work2.playerId.isna().sum()
# Out:
# 0

# %%
work2
# Out:
#            gameDate playerId target1 target2 target3 target4    awardId  \
# 0        2018-01-02   628317  0.0111  4.4747  0.0051  5.7352  MLBSECOND
# 1        2018-01-03   628317  0.0063  2.5210  0.0016  2.7669  MLBSECOND
# 2        2018-01-04   628317  0.0035  2.3809  0.0036  3.4393  MLBSECOND
# 3        2018-01-05   628317  0.0033  3.3323  0.0122  4.8496  MLBSECOND
# 4        2018-01-06   628317  0.0239  1.4407  0.0015  2.3712  MLBSECOND
# ...             ...      ...     ...     ...     ...     ...        ...
# 6495689         NaN   622256     NaN     NaN     NaN     NaN        NaN
# 6495690         NaN   676604     NaN     NaN     NaN     NaN        NaN
# 6495691         NaN   664875     NaN     NaN     NaN     NaN        NaN
# 6495692         NaN   666163     NaN     NaN     NaN     NaN        NaN
# 6495693         NaN   670955     NaN     NaN     NaN     NaN        NaN
#
#                    awardName   awardDate awardSeason   playerName  \
# 0        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 1        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 2        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 3        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# 4        All-MLB Second Team  2020-12-09        2020  Kenta Maeda
# ...                      ...         ...         ...          ...
# 6495689                  NaN         NaN         NaN          NaN
# 6495690                  NaN         NaN         NaN          NaN
# 6495691                  NaN         NaN         NaN          NaN
# 6495692                  NaN         NaN         NaN          NaN
# 6495693                  NaN         NaN         NaN          NaN
#
#         awardPlayerTeamId atBats  rbi homeRuns
# 0                     142    NaN  NaN      NaN
# 1                     142    NaN  NaN      NaN
# 2                     142    NaN  NaN      NaN
# 3                     142    NaN  NaN      NaN
# 4                     142    NaN  NaN      NaN
# ...                   ...    ...  ...      ...
# 6495689               NaN    0.0  0.0      0.0
# 6495690               NaN    1.0  0.0      0.0
# 6495691               NaN    0.0  0.0      0.0
# 6495692               NaN    3.0  1.0      0.0
# 6495693               NaN    1.0  0.0      0.0
#
# [6495694 rows x 15 columns]

# %%
# work2.gameDate.dropna(axis=0, inplace=True)

# %%
work2.gameDate.replace('engagementMetricsDate', np.nan, inplace=True)

# %%
work2.gameDate.dropna(inplace=True, axis=0)

# %%
work2.isna().sum()
# Out:
# gameDate              757870
# playerId                   0
# target1               154290
# target2               154290
# target3               154290
# target4               154290
# awardId               154290
# awardName             154290
# awardDate             154290
# awardSeason           154290
# playerName            154290
# awardPlayerTeamId     154290
# atBats               6341404
# rbi                  6341404
# homeRuns             6341404
# dtype: int64

# %%
work2.target1.dropna(axis=0, inplace=True)

# %%
work2.drop(['awardId', 'awardPlayerTeamId'], axis=1, inplace=True)

# %%
work2.columns
# Out:
# Index(['gameDate', 'playerId', 'target1', 'target2', 'target3', 'target4',
#        'awardName', 'awardDate', 'awardSeason', 'playerName', 'atBats', 'rbi',
#        'homeRuns'],
#       dtype='object')

# %%
work2.gameDate.dropna(axis=0, inplace=True)

# %%
# work2.replace(np.nan, 'N/A', inplace=True)

# %%
work2.target1.dropna(axis=0, inplace=True)

# %%
work2.drop(['awardSeason'], axis=1, inplace=True)

# %%
work2.head()
# Out:
#      gameDate playerId target1 target2 target3 target4            awardName  \
# 0  2018-01-02   628317  0.0111  4.4747  0.0051  5.7352  All-MLB Second Team
# 1  2018-01-03   628317  0.0063  2.5210  0.0016  2.7669  All-MLB Second Team
# 2  2018-01-04   628317  0.0035  2.3809  0.0036  3.4393  All-MLB Second Team
# 3  2018-01-05   628317  0.0033  3.3323  0.0122  4.8496  All-MLB Second Team
# 4  2018-01-06   628317  0.0239  1.4407  0.0015  2.3712  All-MLB Second Team
#
#     awardDate   playerName atBats  rbi homeRuns
# 0  2020-12-09  Kenta Maeda    NaN  NaN      NaN
# 1  2020-12-09  Kenta Maeda    NaN  NaN      NaN
# 2  2020-12-09  Kenta Maeda    NaN  NaN      NaN
# 3  2020-12-09  Kenta Maeda    NaN  NaN      NaN
# 4  2020-12-09  Kenta Maeda    NaN  NaN      NaN

# %%
work2.gameDate=[str(x).replace('-', '') for x in work2.gameDate]

# %%
work2.gameDate=[float(x) for x in work2.gameDate]

# %%
work2.awardDate=[str(x).replace('-', '') for x in work2.awardDate]

# %%
work2.awardDate.replace('awardDate', np.nan, inplace=True)
work2.awardDate=[float(x) for x in work2.awardDate]
work2.awardDate.dropna(axis=0, inplace=True)

# %%
work2.drop('playerId', axis=1, inplace=True)

# %%
work2.atBats.replace('atBats', np.nan, inplace=True)

# %%
work2.atBats=[float(x) for x in work2.atBats]

# %%
work2.atBats.dropna(axis=0, inplace=True)

# %%
work2.rbi.replace('rbi', np.nan, inplace=True)
work2.rbi=[float(x) for x in work2.rbi]
work2.rbi.dropna(axis=0, inplace=True)

# %%
work2.homeRuns.replace('homeRuns', np.nan, inplace=True)
work2.homeRuns=[float(x) for x in work2.homeRuns]
work2.homeRuns.dropna(axis=0, inplace=True)

# %%
work2.replace('target', np.nan, inplace=True)
work2.target1=[float(x) for x in work2.target1]
work2.target1.dropna(axis=0, inplace=True)

work2.target2=[float(x) for x in work2.target2]
work2.target2.dropna(axis=0, inplace=True)

work2.target3=[float(x) for x in work2.target3]
work2.target3.dropna(axis=0, inplace=True)

work2.target4=[float(x) for x in work2.target4]
work2.target4.dropna(axis=0, inplace=True)

# %%
#loading LightGBM
import lightgbm as lgb

# %%
from sklearn.model_selection import train_test_split

# %%
obj_feat = list(work2.loc[:, work2.dtypes == 'object'].columns.values)
obj_feat
# Out:
# ['awardName', 'playerName']

# %%
work2['target1'].replace(np.nan, float(1.9281), inplace=True)

# %%
work2
# Out:
#            gameDate  target1  target2  target3  target4            awardName  \
# 0        20180102.0   0.0111   4.4747   0.0051   5.7352  All-MLB Second Team
# 1        20180103.0   0.0063   2.5210   0.0016   2.7669  All-MLB Second Team
# 2        20180104.0   0.0035   2.3809   0.0036   3.4393  All-MLB Second Team
# 3        20180105.0   0.0033   3.3323   0.0122   4.8496  All-MLB Second Team
# 4        20180106.0   0.0239   1.4407   0.0015   2.3712  All-MLB Second Team
# ...             ...      ...      ...      ...      ...                  ...
# 6495689         NaN   1.9281      NaN      NaN      NaN                  NaN
# 6495690         NaN   1.9281      NaN      NaN      NaN                  NaN
# 6495691         NaN   1.9281      NaN      NaN      NaN                  NaN
# 6495692         NaN   1.9281      NaN      NaN      NaN                  NaN
# 6495693         NaN   1.9281      NaN      NaN      NaN                  NaN
#
#           awardDate   playerName  atBats  rbi  homeRuns
# 0        20201209.0  Kenta Maeda     NaN  NaN       NaN
# 1        20201209.0  Kenta Maeda     NaN  NaN       NaN
# 2        20201209.0  Kenta Maeda     NaN  NaN       NaN
# 3        20201209.0  Kenta Maeda     NaN  NaN       NaN
# 4        20201209.0  Kenta Maeda     NaN  NaN       NaN
# ...             ...          ...     ...  ...       ...
# 6495689         NaN          NaN     0.0  0.0       0.0
# 6495690         NaN          NaN     1.0  0.0       0.0
# 6495691         NaN          NaN     0.0  0.0       0.0
# 6495692         NaN          NaN     3.0  1.0       0.0
# 6495693         NaN          NaN     1.0  0.0       0.0
#
# [6495694 rows x 11 columns]

# %%
for feature in obj_feat:
    work2[feature] = pd.Series(work2[feature], dtype="category")

# %%
X= work2.drop(columns=['target1', 'target2', 'target3', 'target4'], axis=1)

y= work2.target1

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

# %%
hyper_params = {
    'task': 'train',
    'objective': 'regression',
    'metric': ['l2', 'auc', 'mse'],
    'learning_rate': 0.1,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'verbose': 3,
    "max_depth": 8,
    "num_leaves": 128,  
    "max_bin": 512,
    "num_iterations": 3000,
    "n_estimators": 1000, 
    'reg_lambda': .5,
    'reg_alpha': .75, 
    
}

# %%
# gbm = lgb.LGBMRegressor(**hyper_params, random_state=0, n_jobs=-1, silent=False)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
gbm = lgb.train(hyper_params, lgb_train, num_boost_round=10, verbose_eval=True)
# Out:
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.976220
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.419350
# [LightGBM] [Debug] init for col-wise cost 0.028596 seconds, init for row-wise cost 0.213833 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038931 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 4546985, number of used features: 7
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] Start training from score 1.926870
# [LightGBM] [Debug] Re-bagging, using 3185210 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183007 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182704 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182275 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182532 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182510 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182046 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182966 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182851 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183524 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182823 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 108 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 109 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182233 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183276 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181841 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183108 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184475 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 111 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 113 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183805 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182638 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183165 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 107 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183087 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 115 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182647 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 116 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182874 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182787 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182620 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182992 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182107 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182503 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183217 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3180377 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182959 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 112 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184092 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182966 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3179811 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182477 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182277 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182431 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182507 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182298 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183132 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183303 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182125 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182959 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182743 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 107 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 111 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181183 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 96 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182238 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 107 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183184 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182489 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182555 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182895 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182796 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3180243 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 116 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182816 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182630 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 117 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182499 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 113 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 113 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183232 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182980 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 110 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 109 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183121 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183846 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 122 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 121 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182701 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 110 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182497 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182976 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182908 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 120 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182047 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183429 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 96 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184004 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181912 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182762 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 121 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184187 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182506 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 120 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 95 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 110 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182982 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184149 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3184954 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3182884 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181869 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183275 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183591 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 126 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181056 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 121 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3181988 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 3183150 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 123 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 110 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 128 and depth = 8

# %%
y_pred=gbm.predict(X_test)

# %%
# y_pred=[round(x,4) for x in y_pred]
# y_pred=[float(x) for x in y_pred]

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(y_pred, y_test, squared=False)
rms
# Out:
# 4.162072293946554

# %%
pd.Series(y_pred).describe()

# %%
pd.Series(y_test).describe()

# %%
pd.Series(y_test).isna().sum()
